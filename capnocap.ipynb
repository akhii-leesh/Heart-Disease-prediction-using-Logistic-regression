# %% [markdown]
# <a href="https://colab.research.google.com/github/akhii-leesh/Heart-Disease-prediction-using-Logistic-regression/blob/main/capnocap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

# %%
from ultralytics import YOLO

model = YOLO('yolov8l.pt')
model.train(data='/content/drive/MyDrive/CapNoCap/data_custom.yaml', epochs=80)

# %%
from ultralytics import YOLO
model = YOLO("/content/drive/MyDrive/CapNoCap2_final/best.pt")
model.predict(source = "/content/drive/MyDrive/CapNoCap2/31.mp4",save = True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/1906) /content/drive/MyDrive/CapNoCap2/31.mp4: 384x640 1 cap, 1 cylinder, 1453.8ms
# video 1/1 (2/1906) /content/drive/MyDrive/CapNoCap2/31.mp4: 384x640 1 cap, 1 cylinder, 1231.0ms
# video 1/1 (3/1906) /content/drive/MyDrive/CapNoCap2/31.mp4: 384x640 1 cap, 1 cylinder, 1230.2ms
# video 1/1 (4/1906) /content/drive/MyDrive/CapNoCap2/31.mp4: 384x640 1 cap, 1 cylinder, 1212.0ms
# ...
